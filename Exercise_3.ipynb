# %% [markdown]
# <a href="https://colab.research.google.com/github/Md-Hasib-Askari/deep_learning_exercises/blob/main/Exercise_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Exercise 3: Visualizing Activation Functions
#
#
# **Objective:**
# Understand how different activation functions (ReLU, Sigmoid, Tanh) transform data and affect learning in neural networks.
#
#
# **📘 Explanation of Each Activation:**
#
# | Activation | Formula | Characteristics |
# |---|---|---|
# | **ReLU**   | `f(x) = max(0, x)` | Fast, sparse output, widely used in CNNs |
# | **Sigmoid**| `f(x) = 1 / (1 + e^-x)` | Smooth curve, used in binary classification, suffers from vanishing gradients |
# | **Tanh**   | `f(x) = (e^x - e^-x)/(e^x + e^-x)` | Output in [-1, 1], zero-centered, still can vanish |

# %% [markdown]
# ### **📦 Step 1: Import Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ### **📈 Step 2: Define Input Range**

# %%
x = np.linspace(-10, 10, 100) # [-10, ..., 10] - total 1000 values

# %% [markdown]
# ### **⚙️ Step 3: Define Activation Functions**

# %%
# Using NumPy for visual comparison
relu = np.maximum(0, x)
sigmoid = 1 / (1 + np.exp(-x))
tanh = (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

# %% [markdown]
# ### **🎨 Step 4: Plot the Activation Functions**

# %%
plt.figure(figsize=(12, 4))

# ReLU
plt.subplot(1, 3, 1)
plt.plot(x, relu, label="ReLU", color="red")
plt.title("ReLU")
plt.grid(True)

# Sigmoid
plt.subplot(1, 3, 2)
plt.plot(x, sigmoid, label="Sigmoid", color="green")
plt.title("Sigmoid")
plt.grid(True)

# Tanh
plt.subplot(1, 3, 3)
plt.plot(x, tanh, label="Tanh", color="blue")
plt.title("Tanh")
plt.grid(True)

plt.tight_layout()
plt.show()
